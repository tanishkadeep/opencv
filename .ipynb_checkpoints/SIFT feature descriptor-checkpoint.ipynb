# %%
import cv2
import matplotlib.pyplot as plt

img1 = cv2.imread('f2.png', 0)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(img1, None)

img_with_kp = cv2.drawKeypoints(img1, kp, None)
plt.imshow(img_with_kp)
